# %% [markdown]
# # Assignment 3 Walkthrough: Data Analysis and Clustering
#
# Use this notebook to practice the pandas, visualization, and clustering ideas behind Assignment 3. The notebook is a scaffold, not an answer key.

# %% [markdown]
# ## Learning Goals
#
# - Load a CSV file into a pandas DataFrame.
# - Inspect, clean, and summarize a real dataset.
# - Filter rows using multiple conditions.
# - Create labeled visualizations.
# - Apply K-means clustering and interpret the output cautiously.

# %% [markdown]
# ## Dataset Setup
#
# Assignment 3 uses `all_bikez_curated.csv`. Place that file in the same folder as this notebook or update `DATA_PATH` below to point to the correct location.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.manifold import TSNE

DATA_PATH = "all_bikez_curated.csv"

# %% [markdown]
# ## Section 1: Load and Inspect Data
#
# Before cleaning or modeling, always look at the shape, column names, first rows, and data types.

# %%
# TODO: read the CSV into a DataFrame named motorcycle_info.
motorcycle_info = None

# TODO: display the first rows.
motorcycle_info

# %%
# Checkpoint: inspect structure.
# TODO: print shape, columns, and info.

# %% [markdown]
# ## Section 2: Cleaning Decisions
#
# Some columns may look numeric but arrive as text. For example, a column can contain commas or mixed formatting. Clean only after checking the actual values and types.

# %%
# TODO: inspect suspicious columns before converting them.
# Example pattern:
# motorcycle_info["Column name"].head()

# %%
# TODO: drop rows with missing values after deciding this is appropriate.
# motorcycle_info = motorcycle_info.dropna()

# TODO: confirm the cleaned DataFrame.

# %% [markdown]
# ## Section 3: Brands, Numeric Columns, and Correlation
#
# Use pandas methods to summarize categorical and numerical columns. Correlation can suggest relationships, but it does not prove causation.

# %%
# TODO: find all unique brands.
brands = None
brands

# %%
# TODO: select numeric columns into motorcycle_info_num.
motorcycle_info_num = None

# TODO: use describe() and corr() to summarize numeric columns.

# %%
# Checkpoint prompts:
# 1. What percentage of motorcycles have displacement <= 1198 ccm?
# 2. Which three numeric features are most correlated with torque?

# %% [markdown]
# ## Section 4: Filtering with Multiple Conditions
#
# Use parentheses around each condition and combine conditions with `&` for AND.

# %%
# TODO: filter for Yamaha sport motorcycles with displacement greater than 950 ccm.
yamaha_sport_motorcycles = None
yamaha_sport_motorcycles

# %% [markdown]
# ## Section 5: Visualization
#
# Good plots should have readable labels, a title, and a figure size that lets viewers actually compare values.

# %%
# TODO: create a scatter matrix for displacement, torque, power, and dry weight.

# %%
# TODO: find the top 15 brands by count.
top_15_brands = None

# TODO: create a horizontal bar plot with labels.

# %% [markdown]
# ## Section 6: K-means Clustering
#
# K-means needs numeric features. Clusters are not automatically meaningful labels; they are groups created from the features you provide.

# %%
# TODO: fit K-means with k = 3 on the numeric data.
kmeans = None
clusters = None

# %%
# Optional visualization scaffold using t-SNE.
# This reduces many numeric columns to two dimensions for plotting.

# tsne = TSNE(n_components=2, random_state=0)
# reduced_features = tsne.fit_transform(motorcycle_info_num)
# plt.scatter(reduced_features[:, 0], reduced_features[:, 1], c=clusters, cmap="viridis")
# plt.xlabel("Dimension 1")
# plt.ylabel("Dimension 2")
# plt.title("K-means clusters, visualized in two dimensions")
# plt.show()

# %% [markdown]
# ## Wrap-up Questions
#
# 1. Which columns required cleaning before analysis?
# 2. Which plots were most useful for understanding the dataset?
# 3. What should we be careful about when interpreting clusters?
