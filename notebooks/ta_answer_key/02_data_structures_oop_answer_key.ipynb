# %% [markdown]
# # Notebook 02: Data Structures and Object-Oriented Programming
#
# ## Session Overview
# Practice strings, lists, tuples, dictionaries, lists of dictionaries, and simple classes.
#
# These TF notebooks are practice materials. They reinforce lecture notes and John V. Guttag, *Introduction to Computation and Programming Using Python*, Third Edition. They do not replace lecture or reading.

# %% [markdown]
# ## Learning Goals
# - Use strings, lists, tuples, and dictionaries.
# - Choose an appropriate data structure.
# - Loop over data structures.
# - Build and use a simple Python class.
# - Organize a small gradebook program.

# %% [markdown]
# ## Warm-up Questions
# 1. Where might you see a list in real life?
# 2. What information belongs in a student profile?
# 3. Why might we group data and behavior into one class?

# %% [markdown]
# ## Section 1: Strings
#
# Strings are text. You can index, slice, clean, split, and format them.

# %%
message = "  Welcome to Python Club!  "
print(message.strip())
print(message.lower())
print(message.upper())
print(message.strip().split())
print(message[2:9])

# %% [markdown]
# ### Exercise 1.1: Extract Username from Email

# %%
email = "student@example.com"

username = email.split("@")[0]
print(username)

# %% [markdown]
# ### Exercise 1.2: Clean Messy User Input

# %%
raw_subject = "  MaTh  "

clean_subject = raw_subject.strip().lower()
print(clean_subject)

# %% [markdown]
# ### Exercise 1.3: Count Words in a Sentence

# %%
sentence = "Python helps us solve interesting problems"

word_count = len(sentence.split())
print(word_count)

# %% [markdown]
# **TA Note:** Expected outputs: student, math, and 6.
#
# **Hint to give:** Ask which string method separates words.
#
# **Common student mistakes:** Using fixed indices for email without considering username length.

# %% [markdown]
# ## Section 2: Lists
#
# Lists store ordered collections. They can grow, shrink, and be looped over.

# %%
scores = [88, 92, 75]
print(scores)
scores.append(95)
print(scores)
# Out:
# [88, 92, 75]
# [88, 92, 75, 95]

# %%
print("Highest:", max(scores))
print("Average:", sum(scores) / len(scores))

# %% [markdown]
# ### Exercise 2.1: Shopping Cart

# %%
cart = ["notebook", "pencil"]
print(cart)
cart.append("calculator")
print(cart)
cart.remove("pencil")
print(cart)
# Out:
# ['notebook', 'pencil']
# ['notebook', 'pencil', 'calculator']
# ['notebook', 'calculator']

# %% [markdown]
# ### Exercise 2.2: Quiz Scores

# %%
quiz_scores = [91, 84, 97, 73, 90]

average_score = sum(quiz_scores) / len(quiz_scores)
scores_above_90 = []
for score in quiz_scores:
    if score > 90:
        scores_above_90.append(score)

print(average_score)
print(scores_above_90)
# Out:
# 87.0
# [91, 97]

# %% [markdown]
# **TA Note:** Expected average is 87.0 and scores above 90 are [91, 97].
#
# **Hint to give:** Ask students to first solve average, then filtering.
#
# **Common student mistakes:** Using >= 90 when the prompt says above 90.

# %% [markdown]
# ## Section 3: Tuples
#
# Tuples are ordered like lists, but they are immutable. They are useful for fixed pairs such as coordinates.

# %%
point = (3, 4)
x, y = point
print(x, y)
print((x ** 2 + y ** 2) ** 0.5)
# Out:
# 3 4
# 5.0

# %% [markdown]
# ### Exercise 3.1: Coordinates and Distance from Origin

# %%
coordinate = (5, 10)
x, y = coordinate
distance = (x ** 2 + y ** 2) ** 0.5
print(distance)
# Out:
# 11.180339887498949

# %% [markdown]
# ## Section 4: Dictionaries
#
# Dictionaries store key-value pairs. They are good for labeled information.

# %%
student = {
    "name": "Lina",
    "grade_level": 11,
    "favorite_subject": "chemistry",
}
student["grade_level"] = 12
for key, value in student.items():
    print(key, "->", value)
# Out:
# name -> Lina
# grade_level -> 12
# favorite_subject -> chemistry

# %% [markdown]
# ### Exercise 4.1: Student Profile and Course Grades

# %%
profile = {
    "name": "Owen",
    "grade_level": 10,
    "grades": {"math": 92, "english": 87, "science": 95},
}
average = sum(profile["grades"].values()) / len(profile["grades"])
print(f"{profile['name']} is in grade {profile['grade_level']} with average {average:.1f}.")
# Out:
# Owen is in grade 10 with average 91.3.

# %% [markdown]
# **TA Note:** Students should use nested dictionary values for grades.
#
# **Hint to give:** Ask: where should all course scores live?
#
# **Common student mistakes:** Trying to average dictionary keys instead of dictionary values.

# %% [markdown]
# ## Section 5: Lists of Dictionaries
#
# A list of dictionaries is a simple way to represent rows of tabular data.

# %%
students = [
    {"name": "Ava", "major_interest": "biology", "scores": [90, 95]},
    {"name": "Ben", "major_interest": "business", "scores": [82, 78]},
    {"name": "Carmen", "major_interest": "biology", "scores": [96, 94]},
]

for student in students:
    average = sum(student["scores"]) / len(student["scores"])
    print(student["name"], average)
# Out:
# Ava 92.5
# Ben 80.0
# Carmen 95.0

# %% [markdown]
# ### Exercise 5.1: Filter Student Records and Count Interests

# %%
records = [
    {"name": "Ava", "interest": "biology", "average": 92},
    {"name": "Ben", "interest": "business", "average": 84},
    {"name": "Carmen", "interest": "biology", "average": 95},
    {"name": "Dev", "interest": "computer science", "average": 89},
]

high_averages = []
interest_counts = {}
for record in records:
    if record["average"] > 90:
        high_averages.append(record["name"])
    interest = record["interest"]
    interest_counts[interest] = interest_counts.get(interest, 0) + 1
print(high_averages)
print(interest_counts)
# Out:
# ['Ava', 'Carmen']
# {'biology': 2, 'business': 1, 'computer science': 1}

# %% [markdown]
# **TA Note:** Expected high averages: Ava and Carmen.
#
# **Hint to give:** Ask students to solve filtering first, then counting.
#
# **Common student mistakes:** Forgetting to initialize a count for new interests.

# %% [markdown]
# ## Section 6: Object-Oriented Programming
#
# A class is a blueprint. An object is one example made from that blueprint.

# %%
class Student:
    def __init__(self, name, grade_level, scores):
        self.name = name
        self.grade_level = grade_level
        self.scores = scores

    def average_score(self):
        return sum(self.scores) / len(self.scores)

    def is_passing(self):
        return self.average_score() >= 60

student = Student("Nora", 11, [88, 91, 85])
print(student.name)
print(student.average_score())
print(student.is_passing())
# Out:
# Nora
# 88.0
# True

# %% [markdown]
# ### Exercise 6.1: Build a Movie Class

# %%
class Movie:
    def __init__(self, title, genre, rating):
        self.title = title
        self.genre = genre
        self.rating = rating

    def recommendation(self):
        return f"If you like {self.genre}, try {self.title}. It has a rating of {self.rating}."

movie = Movie("Hidden Figures", "drama", 8.0)
print(movie.recommendation())
# Out:
# If you like drama, try Hidden Figures. It has a rating of 8.0.

# %% [markdown]
# **TA Note:** Any clear recommendation sentence is acceptable.
#
# **Hint to give:** Ask: what data does each movie object need to remember?
#
# **Common student mistakes:** Forgetting self, or using local variables instead of attributes.

# %% [markdown]
# ## Section 7: Mini Project
#
# Build a simple gradebook:
#
# - Store multiple students.
# - Add scores.
# - Calculate each student's average.
# - Print a class summary.

# %%
class Student:
    def __init__(self, name, grade, scores):
        self.name = name
        self.grade = grade          # e.g., year or class
        self.scores = scores

    def average_score(self):
        if not self.scores:          # avoid division by zero
            return 0.0
        return sum(self.scores) / len(self.scores)

    def is_passing(self, threshold=60):
        # You can change the threshold as needed
        return self.average_score() >= threshold

# %%
gradebook = [
    Student("Ava", 10, [90, 92, 88]),
    Student("Ben", 10, [78, 81, 84]),
    Student("Carmen", 10, [95, 97, 94]),
]

class_total = 0
for student in gradebook:
    avg = student.average_score()
    class_total += avg
    print(f"{student.name}: {avg:.1f} ({'passing' if student.is_passing() else 'not passing'})")

print(f"Class average: {class_total / len(gradebook):.1f}")
# Out:
# Ava: 90.0 (passing)
# Ben: 81.0 (passing)
# Carmen: 95.3 (passing)
# Class average: 88.8

# %% [markdown]
# **TA Note:** Expected class average with the example is about 89.0.
#
# **Hint to give:** Encourage students to reuse the Student class.
#
# **Common student mistakes:** Rewriting average logic in many places instead of using the method.

# %% [markdown]
# ## Reflection Questions
# 1. When should you use a list?
# 2. When should you use a dictionary?
# 3. When is a class useful?

# %% [markdown]
# ## Optional Extension for Advanced Students
# Add a method to `Student` that returns a letter grade.
