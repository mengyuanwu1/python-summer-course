# %% [markdown]
# # Notebook 03: Algorithms First, Assignment 2 Bridge
#
# This notebook is intentionally shorter than a full algorithms unit. The first part gives you a compact set of algorithm exercises you can do on your own. The second part prepares you for Assignment 2 by building the background for randomness and NBA-series simulations.
#
# The goal is not to copy final homework answers. The goal is to learn how to design small functions, trace state, and debug partial code.

# %% [markdown]
# ## Learning Goals
#
# By the end of this session, you should be able to:
#
# - Translate plain-English steps into a loop.
# - Use linear search and simple edge-case tests.
# - Explain why sorted data makes binary search possible.
# - Match simple algorithms to growth patterns like constant, linear, logarithmic, and quadratic.
# - Use `np.random.choice` to model random outcomes.
# - Plan the state variables for a best-of-7 series simulation.

# %% [markdown]
# # Part 1: Algorithm Exercises
#
# These exercises are designed to be doable in one focused sitting. Do not try to memorize solutions. For each one, write the English idea first, then code.

# %% [markdown]
# ## Exercise 1: Largest Number by Hand
#
# Write a function `find_largest(numbers)`.
#
# Before coding, answer:
#
# 1. What should `largest` be before the loop starts?
# 2. What should happen when you see a number bigger than `largest`?
# 3. What should happen for a one-item list?

# %%
def find_largest(numbers):
    # TODO: choose an initial largest value
    # TODO: loop through numbers
    # TODO: update largest when needed
    # TODO: return largest
    pass

print(find_largest([4, 9, 2, 10, 3]))  # expected: 10
print(find_largest([-5, -2, -9]))       # expected: -2

# %% [markdown]
# ## Exercise 2: Linear Search with Edge Cases
#
# Write `linear_search(items, target)` so it returns the index of `target`, or `-1` if the target is absent.
#
# Edge cases to test:
#
# - Empty list
# - Target at the first position
# - Target at the last position
# - Target absent
# - Target appears more than once

# %%
def linear_search(items, target):
    # TODO: loop over indexes and items
    # TODO: return the first matching index
    # TODO: return -1 if no match is found
    pass

print(linear_search([], "Ava"))
print(linear_search(["Ava", "Ben", "Carmen"], "Ava"))
print(linear_search(["Ava", "Ben", "Carmen"], "Carmen"))
print(linear_search(["Ava", "Ben", "Carmen"], "Dev"))
print(linear_search(["Ava", "Ben", "Ava"], "Ava"))

# %% [markdown]
# ## Exercise 3: Search a List of Dictionaries
#
# A common pattern in real data: each item is a dictionary, and you search by one field.
#
# Write `find_movie(movies, title)` so it returns the index of the movie with that title, or `-1` if absent.

# %%
movies = [
    {"title": "Hidden Figures", "rating": 8.0},
    {"title": "Wall-E", "rating": 8.4},
    {"title": "Spirited Away", "rating": 8.6},
]

def find_movie(movies, title):
    # TODO: loop over movies with indexes
    # TODO: compare the "title" field
    # TODO: return the index, not the whole dictionary
    pass

print(find_movie(movies, "Wall-E"))        # expected: 1
print(find_movie(movies, "Inside Out"))    # expected: -1

# %% [markdown]
# ## Exercise 4: Binary Search Trace, Not Full Implementation
#
# Binary search only works when the list is sorted.
#
# For the list below, trace `low`, `mid`, and `high` by hand until the target is found. The code skeleton prints the variables; fill in the update rules.

# %%
sorted_numbers = [1, 3, 5, 7, 9, 11, 13, 15]
target = 11

low = 0
high = len(sorted_numbers) - 1

while low <= high:
    mid = (low + high) // 2
    print("low/mid/high:", low, mid, high, "value:", sorted_numbers[mid])

    if sorted_numbers[mid] == target:
        print("found at", mid)
        break
    elif sorted_numbers[mid] < target:
        # TODO: target must be to the right
        pass
    else:
        # TODO: target must be to the left
        pass

# %% [markdown]
# ## Exercise 5: Complexity Cards
#
# For each task, write one of: `constant`, `linear`, `logarithmic`, `quadratic`.
#
# 1. Read `items[5]` from a list.
# 2. Search every name until you find "Carmen".
# 3. Binary search in a sorted list.
# 4. Compare every pair of students in a class.
# 5. Two nested loops over the same list.

# %%
complexity_answers = {
    1: "TODO",
    2: "TODO",
    3: "TODO",
    4: "TODO",
    5: "TODO",
}

complexity_answers

# %% [markdown]
# # Part 2: Assignment 2 Bridge
#
# The homework asks you to simulate NBA Finals series. We will not put full homework solutions here. Instead, we will build the background pieces together:
#
# 1. How `np.random` works.
# 2. How to make one random win/loss outcome.
# 3. How to trace one best-of-7 series.
# 4. How to design the state variables for `single_series`.

# %% [markdown]
# ## Background: What is `np.random`?
#
# `np` is the usual nickname for NumPy:
#
# ```python
# import numpy as np
# ```
#
# `np.random` is NumPy's randomness module. In Assignment 2, we use it to simulate outcomes that are uncertain.
#
# Useful functions:
#
# - `np.random.choice(options, p=probabilities)` chooses one item from a list of options.
# - `np.random.uniform()` returns a random number between 0 and 1.
# - `np.random.seed(...)` makes random results repeatable while debugging.

# %%
import numpy as np

np.random.seed(1)

# Choose between two labels with equal probability.
print(np.random.choice(["A wins", "B wins"]))

# Choose between 0 and 1, where 1 has probability 0.7.
print(np.random.choice([0, 1], p=[0.3, 0.7]))

# Draw a random grade between 0 and 1.
print(np.random.uniform())

# %% [markdown]
# ## Homework Function 1: `generate_bernoulli(p)`
#
# A Bernoulli random variable returns either `0` or `1`.
#
# For Assignment 2, interpret:
#
# - `1` as success / team A wins
# - `0` as failure / team A does not win
#
# Planning questions before code:
#
# 1. What are the possible outputs?
# 2. If output `1` has probability `p`, what probability should output `0` have?
# 3. Which `np.random` function lets us choose from `[0, 1]` with custom probabilities?

# %%
def generate_bernoulli(p):
    # TODO: use np.random.choice
    # options should be [0, 1]
    # probabilities should add to 1
    pass

np.random.seed(1)
for _ in range(10):
    print(generate_bernoulli(0.6))

# %% [markdown]
# ## Debugging `generate_bernoulli`
#
# After the function works once, test it many times and inspect the average. If `p = 0.6`, the sample mean should be near 0.6, but not exactly equal every time.

# %%
np.random.seed(1)
results = []

for _ in range(1000):
    results.append(generate_bernoulli(0.6))

print("sample mean:", np.mean(results))
print("first 20 results:", results[:20])

# %% [markdown]
# ## Homework Function 2: Planning `single_series(team_A, team_B, p_A)`
#
# Before writing code, design the state.
#
# Inputs:
#
# - `team_A`: name of team A
# - `team_B`: name of team B
# - `p_A`: probability that team A wins one game
#
# Outputs:
#
# - `n_games`: how many games were played
# - `winner`: final series winner
# - `game_record`: history of game winners
#
# State variables to consider:
#
# - `team_A_wins`
# - `team_B_wins`
# - `n_games`
# - `game_record`
# - one-game winner

# %% [markdown]
# ## Trace One Series By Hand
#
# Fill this table before coding. Use any made-up sequence of game winners, such as A, B, A, A, B, A.
#
# | Game | Game winner | A wins | B wins | Stop? |
# | --- | --- | --- | --- | --- |
# | 1 |  |  |  |  |
# | 2 |  |  |  |  |
# | 3 |  |  |  |  |
# | 4 |  |  |  |  |
# | 5 |  |  |  |  |
# | 6 |  |  |  |  |
# | 7 |  |  |  |  |
#
# Question: what exact condition means the series is over?

# %% [markdown]
# ## Build `single_series` in Small Pieces
#
# Do not try to write everything at once.
#
# Suggested build order:
#
# 1. Initialize counters and an empty `game_record`.
# 2. Simulate one game winner using `np.random.choice` or `generate_bernoulli`.
# 3. Update the correct team's counter.
# 4. Append one record to `game_record`.
# 5. Check whether either team has reached 4 wins.
# 6. Return the final summary.

# %%
def single_series(team_A, team_B, p_A):
    game_record = []
    n_games = 0
    team_A_wins = 0
    team_B_wins = 0

    # TODO: repeat games until one team reaches 4 wins
    # TODO: simulate one game winner
    # TODO: update counters
    # TODO: append to game_record
    # TODO: stop at the right time
    # TODO: return n_games, winner, game_record
    pass

np.random.seed(1)
result = single_series("Golden State Warriors", "Boston Celtics", 0.6)
print(result)

# %% [markdown]
# ## Mini Tests for `single_series`
#
# When your function is partially working, ask:
#
# 1. Does `n_games` always end between 4 and 7?
# 2. Does the final winner have exactly 4 wins in the record?
# 3. Does `game_record` have the same length as `n_games`?
# 4. If `p_A` is very high, does team A usually win?
# 5. If `p_A = 0.5`, do the two teams win at roughly similar rates after many simulations?

# %%
# Use these after single_series is implemented.

# result = single_series("A", "B", 0.9)
# n_games, winner, game_record = result
# print("n_games:", n_games)
# print("winner:", winner)
# print("record:", game_record)
# print("record length matches n_games:", len(game_record) == n_games)

# %% [markdown]
# ## Reflection
#
# Before leaving, write one sentence for each prompt:
#
# 1. What does `np.random.choice` do?
# 2. What state variables does a best-of-7 simulation need?
# 3. What is one bug that could cause an infinite loop?
# 4. What should you test before running 10,000 simulations?
