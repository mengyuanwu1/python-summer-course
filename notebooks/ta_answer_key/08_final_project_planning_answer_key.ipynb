# %% [markdown]
# # Notebook 08: Final Project Planning
#
# ## Session Overview
# Plan an individual final project with a clear WHAT, HOW, and WHY. The syllabus requires an individual 5-minute final presentation and an individual written report of up to 8 pages, with at least five scholarly sources.
#
# These TF notebooks are practice materials. They reinforce lecture notes and John V. Guttag, *Introduction to Computation and Programming Using Python*, Third Edition. They do not replace lecture or reading.

# %% [markdown]
# ## Learning Goals
# - Choose a feasible project type.
# - State a computational question.
# - Plan the dataset, method, figures, citations, and milestones.
# - Connect the project to the WHAT, HOW, and WHY requirement.

# %% [markdown]
# ## Warm-up Questions
# 1. What topic are you curious about?
# 2. What dataset or code source might support that topic?
# 3. What would make the project too large for the time available?

# %% [markdown]
#             ## Section 1: Final Project Overview
#
#             The final project is individual. You may either run your own Python/ML experiment or critically analyze existing Kaggle/GitHub/tutorial code. Your project must explain:
#
#             - WHAT: topic and main question
#             - HOW: method, code, data, and evaluation
#             - WHY: motivation, case-study value, and literature context
#
#             Example project topics:
#
#             - Iris classification with KNN and decision trees
# - Student performance prediction
# - Simple stock-price trend exploration
# - Customer segmentation with K-means
# - Handwritten digit classification with a simple neural network
# - Multi-armed bandit simulation

# %% [markdown]
# ## Section 2: Choose Project Type
#
# Choose one:
#
# - original Python/ML experiment
# - analysis of existing Kaggle/GitHub/tutorial code

# %%
project_type = "original Python/ML experiment"
print(project_type)

# %% [markdown]
# ## Section 3: Topic Selection Worksheet

# %%
import pandas as pd

topic_worksheet = pd.DataFrame([
    {"Prompt": "Topic area", "Answer": "Customer segmentation"},
    {"Prompt": "Why it interests me", "Answer": "Businesses use groups to understand customers."},
    {"Prompt": "Main question", "Answer": "Can K-means find useful customer groups?"},
    {"Prompt": "Course concepts used", "Answer": "pandas, visualization, K-means, PCA"},
])
topic_worksheet

# %% [markdown]
# ## Section 4: Dataset/Repository Worksheet

# %%
source_worksheet = pd.DataFrame([
    {"Item": "Dataset or repository", "Plan": "toy_customer_data.csv, then a small Kaggle customer dataset if time allows"},
    {"Item": "Source link or citation", "Plan": "Course toy data; Kaggle source if used"},
    {"Item": "Rows/features", "Plan": "Customer age, annual spending, website visits"},
    {"Item": "Possible issue", "Plan": "Toy data is small and synthetic"},
])
source_worksheet

# %% [markdown]
# ## Section 5: WHAT/HOW/WHY Planning Table

# %%
what_how_why = pd.DataFrame([
    {"Part": "WHAT", "Answer": "Customer segmentation using spending and website visits"},
    {"Part": "HOW", "Answer": "Clean data, standardize features, run K-means, visualize with PCA"},
    {"Part": "WHY", "Answer": "Segmentation is common in business analytics and helps explain unsupervised learning"},
])
what_how_why

# %% [markdown]
# ## Section 6: Method Planning

# %%
method_plan = pd.DataFrame([
    {"Step": "Load data", "Tool": "pandas", "Output": "DataFrame"},
    {"Step": "Clean/inspect", "Tool": "pandas", "Output": "Missing-value summary"},
    {"Step": "Model", "Tool": "KMeans", "Output": "Cluster labels"},
    {"Step": "Evaluate/interpret", "Tool": "PCA and charts", "Output": "Cluster report"},
])
method_plan

# %% [markdown]
# ## Section 7: Expected Figures/Tables

# %%
expected_outputs = pd.DataFrame([
    {"Type": "Figure", "Description": "Scatter plot of spending vs visits colored by cluster"},
    {"Type": "Figure", "Description": "PCA cluster plot"},
    {"Type": "Table", "Description": "Mean age/spending/visits by cluster"},
])
expected_outputs

# %% [markdown]
# ## Section 8: Citation Checklist

# %%
citation_checklist = pd.DataFrame([
    {"Requirement": "At least five scholarly sources", "Status": "Need to collect"},
    {"Requirement": "Dataset or code source cited", "Status": "Course data cited; Kaggle source if used"},
    {"Requirement": "Textbook or lecture connection", "Status": "Guttag and lecture notes"},
    {"Requirement": "No uncited copied code", "Status": "Will cite any tutorial code"},
])
citation_checklist

# %% [markdown]
# ## Section 9: Feasibility Checklist

# %%
feasibility = pd.DataFrame([
    {"Check": "Can run without private API keys", "Answer": "Yes"},
    {"Check": "Dataset is small enough", "Answer": "Yes"},
    {"Check": "Method matches current skills", "Answer": "Yes"},
    {"Check": "Can explain in 5 minutes", "Answer": "Yes, if I focus on one method"},
])
feasibility

# %% [markdown]
# ## Section 10: Milestone Checklist Before Session 9

# %%
milestones = pd.DataFrame([
    {"Milestone": "Question written clearly", "Done": True},
    {"Milestone": "Data loaded successfully", "Done": True},
    {"Milestone": "One baseline chart made", "Done": False},
    {"Milestone": "One draft slide outline made", "Done": False},
    {"Milestone": "One debugging question prepared", "Done": False},
])
milestones

# %% [markdown]
# ## Debugging or Common Mistakes Section
#
# - Scope is too broad.
# - Dataset is too large or hard to access.
# - Method does not answer the question.
# - WHY section is missing scholarly context.

# %% [markdown]
# ## Challenge Exercise
#
# Write a one-page project proposal with WHAT, HOW, WHY, expected figure, limitation, and five source ideas.

# %% [markdown]
# **TA Note:** The example project is intentionally modest and explainable.
#
# **Hint to give:** Ask students to reduce the scope until it fits one sentence.
#
# **Common student mistakes:** Choosing a topic because it sounds advanced but cannot be run or explained.

# %% [markdown]
# ## Reflection Questions
# 1. What is your project's WHAT?
# 2. What is your project's HOW?
# 3. What is your project's WHY?

# %% [markdown]
# ## Optional Extension for Advanced Students
# Create a first draft of the final presentation title slide and methods slide.
